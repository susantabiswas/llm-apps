# %%
from openai import AzureOpenAI
import os
from dotenv import load_dotenv
import json

from IPython.display import Markdown, display

# %% [markdown]
# ## Load LLM Configurations

# %% [markdown]
# ### Azure OpenAI LLM

# %%
load_dotenv(override=True)
llm_api_key = os.getenv("AZURE_OPENAI_KEY")
azure_oai_endpoint = os.getenv("AZURE_OAI_ENDPOINT")

# %%
openai = AzureOpenAI(
    azure_endpoint = azure_oai_endpoint,
    api_key = llm_api_key,
    api_version = "2025-01-01-preview"
)

# %% [markdown]
# #### Sample Test usage

# %%
message = "Hi"
response = openai.chat.completions.create(
    model = "gpt-4o-mini",
    messages = [{"role": "user", "content": message}]
)

print(response.choices[0].message.content)

messages = [
    {'role': 'system', 'content': "You are a sarcastic assistant"},
    {'role': 'user', 'content': "How is the weather?"}
]

response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
print(messages[1]["content"])
print(response.choices[0].message.content)
# Out:
# Hello! How can I assist you today?
# How is the weather?
# Oh, you know, just the usual—sunshine and rainbows or perhaps a monsoon. It really depends on whether you checked the forecast or just decided to wing it. Why bother with a weather app when you can step outside and see for yourself? It's like a surprise party but for your day!

# %% [markdown]
# ## Website Summarizer
#
# A Website is scraped and its contents are then parsed. This content is then fed to the LLM to get a summary

# %%
from bs4 import BeautifulSoup
import requests

# %%
class Website:
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36"
    }
    
    def __init__(self, url):
        self.url = url
        response = requests.get(url, headers=Website.headers)
        parser = BeautifulSoup(response.content, 'html.parser')

        # get rid of the irreleavnt stuff from body
        for element in parser.body(["script", "style", "img", "input"]):
            element.decompose()
            
        self.title = parser.title.string if parser.title else ""
        self.body = parser.body.get_text(separator="\n", strip=True)

# %%
website = Website("https://edition.cnn.com/")

# %%
print(website.title)
print()
print(website.body)
# Out:
# Breaking News, Latest News and Videos | CNN
#
# CNN values your feedback
# 1. How relevant is this ad to you?
# 2. Did you encounter any technical issues?
# Video player was slow to load content
# Video content never loaded
# Ad froze or did not finish loading
# Video content did not start after ad
# Audio on ad was too loud
# Other issues
# Ad never loaded
# Ad prevented/slowed the page from loading
# Content moved around while ad loaded
# Ad was repetitive to ads I've seen previously
# Other issues
# Cancel
# Submit
# Thank You!
# Your effort and contribution in providing this feedback is much
#                                         appreciated.
# Close
# Ad Feedback
# Close icon
# US
# World
# Politics
# Business
# Health
# Entertainment
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# More
# US
# World
# Politics
# Business
# Health
# Entertainment
# Style
# Travel
# Sports
# Science
# Climate
# Weather
# Ukraine-Russia War
# Israel-Hamas War
# Games
# Watch
# Listen
# Live TV
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics You Follow
# Sign Out
# Your CNN account
# Sign in to your CNN account
# Sign in
# My Account
# Settings
# Newsletters
# Topics You Follow
# Sign Out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# Edition
# US
# International
# Arabic
# Español
# Edition
# US
# International
# Arabic
# Español
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# US Politics
# SCOTUS
# Congress
# Facts First
# 2024 Elections
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Foreseeable Future
# Mission: Ahead
# Work Transformed
# Innovative Cities
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# Football
# Tennis
# Golf
# Motorsport
# US Sports
# Olympics
# Climbing
# Esports
# Hockey
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Features
# As Equals
# Call to Earth
# Freedom Project
# Impact Your World
# Inside Africa
# CNN Heroes
# Watch
# Live TV
# CNN Fast
# Shows A-Z
# CNN10
# CNN Max
# CNN TV Schedules
# Listen
# CNN 5 Things
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# One Thing
# Tug of War
# CNN Political Briefing
# The Axe Files
# All There Is with Anderson Cooper
# All CNN Audio podcasts
# Games
# CNN Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Follow CNN
# Trump’s tariff gamble
# Myanmar earthquake
# France’s far-right
# Hooters files for bankruptcy
# Rhinos baby boom
# How to prevent doomscrolling
# World record ski jump
# Trump has the world on edge as he mulls tariffs
# Show all
# •
# Analysis
# Analysis
# Andrew Harnik/Getty Images
# Analysis
# US president’s still-mysterious April 2 plan could deliver untold economic consequences to billions of people
# Trump is now planning a splashy ‘Liberation Day’ announcement. What he’ll say is still up in the air
# Wall Street is fed up with Trump’s tariffs
# Cory Booker’s marathon Senate floor speech stretches into the night in protest over Trump actions
# Trump administration concedes Maryland father from El Salvador was mistakenly deported and sent to mega prison
# Trump accuses Ukraine’s Zelensky of ‘trying to back out’ of proposed minerals deal
# •
# Video
# 0:41
# POOL
# Video
# Trump asked how he’d feel about running for third term if it were against Obama
# 0:41
# •
# Analysis
# Analysis
# CFOTO/Future Publishing/Getty Images
# Analysis
# China wants to talk trade with the US, but is also ready to fight
# •
# Video
# 2:13
# CNN
# Video
# Elie Honig breaks down ‘loophole’ Trump’s team sees for third term
# 2:13
# Eastern Theatre Command/Handout/Reuters
# China’s military says it’s launching combined drills around Taiwan, testing US resolve
# Bay Ismoyo/AFP/Getty Images
# Flight turns around after passenger tries to force plane door open over Indian Ocean
# •
# Video
# 2:59
# CNN
# Video
# Hear from women who were trapped under rubble after Myanmar earthquake
# 2:59
# Golden rescue window closing three days after quake kills more than 2,000 in Myanmar and Thailand. Here’s what we know
# CNN Fast
# - Source:
# CNN
# Catch up on today’s global news
# SpaceX
# SpaceX launches first-of-its-kind human spaceflight mission
# Kevin Carter/Getty Images/File
# Hooters files for bankruptcy
# Richard A. Brooks/AFP/Getty Images
# Popular Japanese beef bowl chain shuts after rat, bug found in food
# •
# Video
# 1:43
# Clipped From Video
# Video
# Comedians try to figure out who mysterious ‘Jacob’ is in Signal scandal
# 1:43
# Borut Zivulovic/Reuters
# Domen Prevc breaks world record with 254.5-meter ski jump
# Maria Korneeva/Moment RF/Getty Images
# How to prevent doomscrolling from controlling you
# Ad Feedback
# More top stories
# Emily Michot/Miami Herald/TNS/Getty Images/File
# Prince Andrew accuser Virginia Giuffre says she’s dying after a car crash with school bus
# Burst gas pipe sparks colossal fire in Malaysia
# Analysis
# Le Pen seems politically dead after guilty verdict. Can the far-right win in France without her?
# Video
# Military expert reveals what he thinks is Russia’s biggest weakness amid Ukraine war
# 2:23
# Israel again expands Gaza war as Netanyahu vows he’s changing the Middle East. The endgame is unclear
# Bodies of missing aid workers found in Gaza ‘mass grave’ after Israeli attacks
# Amanda Voisard for The Washington Post/Getty Images
# Rhinos were hunted to extinction in this country, but a recent baby boom brings hope
# Phil Noble/Reuters
# Britain’s second-largest city declares ‘major incident’ as 17,000 tons of uncollected garbage left on streets
# Mike Stobe/Getty Images
# What are the ‘torpedo’ bats in MLB that have everyone talking?
# Ad Feedback
# Mindaugas Kulbis/AP
# Bodies of US soldiers whose vehicle was submerged in Lithuania are recovered
# Mar 31, 2025
# CNN
# Video
# Driverless car takes on winding country roads at 60mph
# 2:39
# Mar 24, 2025
# Ashley Landis/AP
# NASA astronauts speak out for first time after unexpected 9-month space mission
# Mar 31, 2025
# Alessandro Serrano/Shutterstock
# Fire at Tesla dealership near Rome destroys 17 cars
# Mar 31, 2025
# Ad Feedback
# Lilit Marcus/CNN
# This airport landing is so tough only 50 pilots are qualified to do it
# Nicolas Economou/NurPhoto/Getty Images
# What’s the riskiest part of your flight? It isn’t cruising at 40,000 feet
# •
# Video
# 1:42
# Ashley Landis/AP
# Video
# ‘It’s a great spacecraft’: Wilmore and Williams praise ship that led to extended stay on ISS
# 1:42
# Chris Jung/NURPHO/AP
# Man caring for ancestors’ grave may have ignited huge South Korea wildfire, police say
# Miles Aldridge Courtesy Sotheby’s
# A photographer makes the case for shooting with film over digital
# cyano66/iStockphoto/Getty Images
# Alzheimer’s risk rises when amount of deep sleep falls, study suggests
# Francois Prost
# UFOs, boats and castles: Surreal photos of Japan’s most peculiar ‘love hotels’
# Joe Maher/Getty Images
# Helen Mirren is no fan of James Bond’s ‘profound sexism’
# Rebecca Blackwell/AP
# Unseeded teen denies idol Novak Djokovic his 100th career title
# •
# Video
# 0:48
# Cindy and Curt Leitschuh
# Video
# Ring camera captures the moment a small plane crashes into a home
# 0:48
# Michal Augustini/Shutterstock
# The Who get real about octogenarian rock star life
# Ad Feedback
# Featured Sections
# Space and science
# NASA
# Curiosity rover makes ‘arguably the most exciting organic detection to date on Mars’
# Wind turbine parts may be giant technofossils that puzzle future scientists
# Fossilized fish up to 16 million years old found in Australia, with last meal still intact
# Scientists redid an experiment that showed how life on Earth could have started. They found a new possibility
# Global Travel
# Show all
# Courtesy The World's 50 Best
# ‘We are not just one city’: Asia’s 50 best restaurants for 2025 revealed
# Why there’s a huge collection of vintage cars stored in the middle of the desert
# Two sisters with no hospitality experience bought a century-old inn. Here’s how it worked out
# Japan’s natural hot springs are running low. Overtourism is to blame
# Ad Feedback
# Global Business
# Paul Faith/AFP/Getty Images
# Primark CEO resigns after ‘error of judgment’
# Looming car tariffs have some Americans rushing to dealerships to avoid sticker shock
# Trump says he ‘couldn’t care less’ if auto prices rise because of tariffs
# ‘A huge blow’: USDA cuts threaten to throw Wisconsin’s local food supply into disarray
# Style
# Richard Baker/In Pictures/Getty Images
# Fashion giant H&M plans to use AI clones of its human models. Not everyone is happy
# Viral Studio Ghibli-style AI images showcase power – and copyright concerns – of ChatGPT update
# Pamela Anderson, ‘explosive’ bikinis and the changing tides of swimwear style
# The cultural impact of Madonna and the 1985 film ‘Desperately Seeking Susan’
# SPORT
# Show all
# Maddie Meyer/Getty Images
# US star Ilia Malinin defends his world figure skating title with breathtaking performance
# The world’s fastest 15-year-old sets his sights on Olympic gold
# Seven ejected following scuffle in Minnesota Timberwolves-Detroit Pistons game
# Alysa Liu becomes first American woman in 19 years to win figure skating world title
# Ad Feedback
# US Politics
# Samuel Corum/Sipa/Getty Images
# Is DOGE actually an agency? The answer could have major ramifications
# CNN Investigates
# Red states could benefit as Trump’s transportation secretary prioritizes funds based on birth and marriage rates
# Florida’s special elections give Trump, GOP leaders more reasons to sweat slim House majority
# Vulnerable Senate Democrat Ossoff seeks to channel Trump outrage on tough road to reelection
# health and wellness
# •
# Analysis
# Analysis
# Maria Korneeva/Moment RF/Getty Images
# Analysis
# How to prevent doomscrolling from controlling you
# Over half of US states are trying to eliminate food dyes. Here’s what you can do now
# Artificial sweetener found in diet drinks linked to brain changes that increase appetite, study finds
# Here’s why you keep waking up to pee in the middle of the night
# Tech
# •
# Analysis
# Analysis
# Kevin Carter/Getty Images
# Analysis
# Apple needs a new reason to get you to buy a new iPhone. It may have one
# Doctor explains how artificial intelligence is already being deployed in medical care
# China is practicing ‘dogfighting’ with satellites as it ramps up space capabilities: US Space Force
# Elon Musk says he sold X to his AI company
# Photos You Should See
# •
# Gallery
# Gallery
# Reuters
# Gallery
# Deadly earthquake strikes Myanmar, Thailand and China
# •
# Gallery
# Gallery
# Sean M. Haffey/Getty Images
# Gallery
# The week in 34 photos
# •
# Gallery
# Gallery
# Courtesy The World's 50 Best
# Gallery
# Asia’s 50 best restaurants for 2025 revealed
# •
# Gallery
# Gallery
# Thomas Lohnes/Getty Images
# Gallery
# Europe’s largest wild animal comes back from the brink
# Bonnie Cash/Bloomberg/Getty Images
# Flags, figurines and gold everywhere: Trump transforms the Oval Office into a gilded gallery
# •
# Gallery
# Gallery
# Karim Sahib/AFP/Getty Images
# Gallery
# Arabian oryx: Back from the brink
# Ad Feedback
# In Case You Missed It
# Javed Iqbal/CNN
# ‘Get us out of here’: Anti-migrant policies leave Afghan pilots fearing for their lives
# This Angolan company is finding global buyers for its cassava and caterpillars
# Queer and trans homesteaders are conquering the social media frontier
# She was set to retire in August, but Milei’s government has dashed her hopes
# Analysis
# Why the American consumer is fed up
# This one thing might cut how much you use your phone in half, study finds
# ‘White Lotus’ villain Jon Gries reveals the true crimes that inspired his twisty take on Greg/Gary
# Judge temporarily halts Trump from canceling Radio Free Europe, handing embattled broadcasters a lifeline
# Takeaways from federal appeals court hearing on Trump’s use of the Alien Enemies Act
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics You Follow
# Sign Out
# Your CNN account
# Sign in to your CNN account
# Live TV
# Listen
# Watch
# World
# Africa
# Americas
# Asia
# Australia
# China
# Europe
# India
# Middle East
# United Kingdom
# US Politics
# SCOTUS
# Congress
# Facts First
# 2024 Elections
# Business
# Tech
# Media
# Calculators
# Videos
# Markets
# Pre-markets
# After-Hours
# Fear & Greed
# Investing
# Markets Now
# Nightcap
# Health
# Life, But Better
# Fitness
# Food
# Sleep
# Mindfulness
# Relationships
# Entertainment
# Movies
# Television
# Celebrity
# Tech
# Innovate
# Foreseeable Future
# Mission: Ahead
# Work Transformed
# Innovative Cities
# Style
# Arts
# Design
# Fashion
# Architecture
# Luxury
# Beauty
# Video
# Travel
# Destinations
# Food & Drink
# Stay
# News
# Videos
# Sports
# Football
# Tennis
# Golf
# Motorsport
# US Sports
# Olympics
# Climbing
# Esports
# Hockey
# Science
# Space
# Life
# Unearthed
# Climate
# Solutions
# Weather
# Weather
# Video
# Climate
# Ukraine-Russia War
# Israel-Hamas War
# Features
# As Equals
# Call to Earth
# Freedom Project
# Impact Your World
# Inside Africa
# CNN Heroes
# Watch
# Live TV
# CNN Fast
# Shows A-Z
# CNN10
# CNN Max
# CNN TV Schedules
# Listen
# CNN 5 Things
# Chasing Life with Dr. Sanjay Gupta
# The Assignment with Audie Cornish
# One Thing
# Tug of War
# CNN Political Briefing
# The Axe Files
# All There Is with Anderson Cooper
# All CNN Audio podcasts
# Games
# CNN Crossword
# Jumble Crossword
# Photo Shuffle
# Sudoblock
# Sudoku
# 5 Things Quiz
# About CNN
# Photos
# Investigations
# CNN Profiles
# CNN Leadership
# CNN Newsletters
# Work for CNN
# Watch
# Listen
# Live TV
# Follow CNN
# Subscribe
# Sign in
# My Account
# Settings
# Newsletters
# Topics You Follow
# Sign Out
# Your CNN account
# Sign in to your CNN account
# Terms of Use
# Privacy Policy
# Ad Choices
# Accessibility & CC
# About
# Newsletters
# Transcripts
# © 2025 Cable News Network. A Warner Bros. Discovery Company. All Rights Reserved.
# CNN Sans ™ & © 2016 Cable News Network.

# %% [markdown]
# ### AI Summarization
#
# We will summarize the contents of a website with the help of a LLM.

# %%
def create_summarization_system_prompt():
    return """You are an assistant which specializes in summarizing text content. You will be provided text content from a website and your task is to write a short summary and follow the below instructions:
    - The summary format should be:
        - Title
        - Overview
        - Summary
    - Ignore any navigation related contents.
    - Output should be in raw markdown format only, without the ```."""

def create_summarization_user_prompt(website: Website):
    prompt = f"""Here is a website with title: {website.title}.
    Summarize the contents of this website and provide summary in markdown.
    The contents of the website are as follows:
    {website.body}
    """
    return prompt

def create_summarization_messages(website: Website):
    return [
        {"role": "system", "content": create_summarization_system_prompt()},
        {"role": "user", "content": create_summarization_user_prompt(website)}
    ]

def summarize_website(url: str):
    website = Website(url)
    response = openai.chat.completions.create(
        model="gpt-4o-mini",
        messages=create_summarization_messages(website)
    )

    return response.choices[0].message.content

def display_markdown(content: str):
    display(Markdown(content))

# %%
summary = summarize_website("https://edition.cnn.com/")
summary
# Out:
# "# Breaking News, Latest News and Videos | CNN\n\n## Overview\nCNN's website features a comprehensive aggregation of the latest global news, videos, and analysis across various topics including politics, business, health, and entertainment.\n\n## Summary\nThe CNN website offers breaking news and in-depth analysis on current events globally. It covers various categories such as US and world news, politics, business, health, and entertainment. The platform also features numerous video segments, podcasts, and newsletters to keep users updated on significant stories, trends, and investigative reports. Additionally, CNN presents interactive content including games like crosswords and quizzes, enhancing user engagement. Users can also submit feedback on advertisements and utilize options for personalized news through account settings."

# %%
display_markdown(summary)
# Out:
# # Breaking News, Latest News and Videos | CNN
#
# ## Overview
# CNN is a leading news platform offering a wide range of content that includes breaking news, in-depth analysis, and video coverage across various topics. The content spans global headlines, politics, business, health, entertainment, science, and sports.
#
# ## Summary
# CNN provides up-to-the-minute news reports on significant global and national events. The website features a multitude of sections including politics, business news, health updates, entertainment highlights, and sports coverage. Current stories cover impactful topics such as the Ukraine-Russia war and international conflicts like the Israel-Hamas situation. Additionally, CNN offers specialized sections dedicated to various interests, including travel, science, and technology, alongside interactive elements like games and video content. Users are encouraged to provide feedback on ads and other experiences, reflecting CNN's commitment to enhancing user engagement and experience.
